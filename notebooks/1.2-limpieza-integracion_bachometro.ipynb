# %% [markdown]
# # 1.2 Preprocesado y Limpieza de datos Bachometro

# %% [markdown]
# ### Carga y lectura del dataset.

# %% [markdown]
# Comenzamos importando los datos desde el path en el que los guardó nuestro Script de extraccion. En este caso, estamos tratando con archivos JSON.

# %%
import pandas as pd

# Cargar el archivo JSON
df = pd.read_json("../../data/raw/baches_2023.json")

# %% [markdown]
# Revisamos el dataframe resultante

# %%
# Mostrar las primeras filas
df.head(5)
# Out:
#     latitude   longitude       date neighborhoods material  \
# 0  29.102150 -110.975015 2022-12-30          [50]  Asfalto
# 1  29.099811 -110.980192 2022-12-30         [397]  Asfalto
# 2  29.139033 -111.007460 2022-12-29         [589]  Asfalto
# 3  29.102135 -111.001896 2022-12-29         [545]  Asfalto
# 4  29.102142 -110.998482 2022-12-29         [545]  Asfalto
#
#                                          description    id no_reparemos  \
# 0  Bacheo en Arizona entre Mendoza y José San Healy.  9027       1/2023
# 1  Bacheo en Callejón Imuris entre José San Healy...  9028       2/2023
# 2    Bacheo en Sierra de las Huertas y Nudo Mixteco.  9029       3/2023
# 3                            Bacheo en Mendoza y 16.  9030       4/2023
# 4                            Bacheo en Mendoza y 10.  9031       5/2023
#
#    folio       fecha_reporte fecha_atencion         colonia  \
# 0    NaN  Diciembre 30, 2022           None      Balderrama
# 1    NaN  Diciembre 30, 2022           None        Olivares
# 2    NaN  Diciembre 29, 2022           None     Solidaridad
# 3    NaN  Diciembre 29, 2022           None  Sahuaro Indeco
# 4    NaN  Diciembre 29, 2022           None  Sahuaro Indeco
#
#                                            direccion  \
# 0  Othon Almada 330-A, C. Arizona esquina, Balder...
# 1  Cjon. Ímuris 56B, Olivares, 83180 Hermosillo, ...
# 2  Nudo Mixteco 193, Solidaridad, 83116 Hermosill...
# 3  Av. José María Mendoza 1509A, Sahuaro Indeco, ...
# 4  Av. José María Mendoza 6, Sahuaro Indeco, 8318...
#
#                                          descripcion  \
# 0  Bacheo en Arizona entre Mendoza y José San Healy.
# 1  Bacheo en Callejón Imuris entre José San Healy...
# 2    Bacheo en Sierra de las Huertas y Nudo Mixteco.
# 3                            Bacheo en Mendoza y 16.
# 4                            Bacheo en Mendoza y 10.
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.tail()
# Out:
#        latitude   longitude       date neighborhoods material  \
# 4886  29.140324 -110.975054 2023-12-28         [729]  Asfalto
# 4887  29.091493 -110.957280 2023-12-28         [551]  Asfalto
# 4888  29.127477 -111.004216 2023-12-28         [614]  Asfalto
# 4889  29.126429 -111.012014 2023-12-28         [729]  Asfalto
# 4890  29.148924 -111.006597 2023-12-28         [462]  Asfalto
#
#                                             description     id no_reparemos  \
# 4886  BACHEO EN REFORMA ENTRE VILLA JUAREZ Y BLVD PR...  14281    5255/2023
# 4887  BACHEO EN ZACATECAS ENTRE GARMENDIA Y FELIX SORIA  14282    5256/2023
# 4888  BACHEO EN JOAQUIN DURAN ENTRE REP DE CUBA Y JU...  14283    5257/2023
# 4889  BACHEO EN JOAQUIN DURAN ESQUINA CARLOS BALDERRAMA  14284    5258/2023
# 4890  BACHEO EN BOSQUES DE REFORMA ESQUINA BLVD AGUS...  14285    5259/2023
#
#       folio       fecha_reporte fecha_atencion               colonia  \
# 4886    NaN  Diciembre 28, 2023           None    Vialidad Principal
# 4887    NaN  Diciembre 28, 2023           None            San Benito
# 4888    NaN  Diciembre 28, 2023           None  Unión de Ladrilleros
# 4889    NaN  Diciembre 28, 2023           None    Vialidad Principal
# 4890    NaN  Diciembre 28, 2023           None   Privadas Del Bosque
#
#                                               direccion  \
# 4886  C. de la Reforma 314, Heberto Castillo, 83106 ...
# 4887  Av. Zacatecas SN-S, San Benito, 83190 Hermosil...
# 4888  Av. Joaquín Gabriel Durán 32, Union De Ladrill...
# 4889  Avenida Joaquin Duran & Calle Carlos Balderram...
# 4890  Blvd Agustin F Zamora, Zona Industrial, 83117 ...
#
#                                             descripcion  \
# 4886  BACHEO EN REFORMA ENTRE VILLA JUAREZ Y BLVD PR...
# 4887  BACHEO EN ZACATECAS ENTRE GARMENDIA Y FELIX SORIA
# 4888  BACHEO EN JOAQUIN DURAN ENTRE REP DE CUBA Y JU...
# 4889  BACHEO EN JOAQUIN DURAN ESQUINA CARLOS BALDERRAMA
# 4890  BACHEO EN BOSQUES DE REFORMA ESQUINA BLVD AGUS...
#
#                                                imagenes
# 4886  [https://bachometro.hermosillo.gob.mx/images/f...
# 4887  [https://bachometro.hermosillo.gob.mx/images/f...
# 4888  [https://bachometro.hermosillo.gob.mx/images/f...
# 4889  [https://bachometro.hermosillo.gob.mx/images/f...
# 4890  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
#Informacion relevante de las columnas del dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4891 entries, 0 to 4890
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        4891 non-null   float64
#  1   longitude       4891 non-null   float64
#  2   date            4891 non-null   datetime64[ns]
#  3   neighborhoods   4891 non-null   object
#  4   material        4891 non-null   object
#  5   description     4891 non-null   object
#  6   id              4891 non-null   int64
#  7   no_reparemos    4891 non-null   object
#  8   folio           318 non-null    float64
#  9   fecha_reporte   4891 non-null   object
#  10  fecha_atencion  323 non-null    object
#  11  colonia         4891 non-null   object
#  12  direccion       4891 non-null   object
#  13  descripcion     4891 non-null   object
#  14  imagenes        4891 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 573.3+ KB

# %% [markdown]
# Eliminamos algunas columnas de texto que no utilizaremos para el futuro análisis entre la relacion entre los baches y accidentes automovilísticos.

# %%
#droppeando laas columnas de descripción ya que no son necesarias para el análisis
df = df.drop(columns=['descripcion'])
df = df.drop(columns=['description'])

# %%
#Revisando valores unicos de Material
df['material'].unique()
# Out:
# array(['Asfalto', 'Concreto'], dtype=object)

# %%
#Graficando la distribución de Material
import matplotlib.pyplot as plt
df['material'].value_counts().plot(kind='bar')
plt.title('Distribución de Material de Baches')
plt.xlabel('Material')
plt.ylabel('Cantidad de Baches')
plt.show()

# %% [markdown]
# Revisando la cantidad de cada material (para varios datasets) resulta insignificante la cantidad de baches en concreto. La informacion que aporta es poco relevante por lo que quitaremos esta columna del dataframe.

# %%
# Droppeando material ya que no aporta informacion relevante
df = df.drop(columns=['material'])

# %%
df.head()
# Out:
#     latitude   longitude       date neighborhoods    id no_reparemos  folio  \
# 0  29.102150 -110.975015 2022-12-30          [50]  9027       1/2023    NaN
# 1  29.099811 -110.980192 2022-12-30         [397]  9028       2/2023    NaN
# 2  29.139033 -111.007460 2022-12-29         [589]  9029       3/2023    NaN
# 3  29.102135 -111.001896 2022-12-29         [545]  9030       4/2023    NaN
# 4  29.102142 -110.998482 2022-12-29         [545]  9031       5/2023    NaN
#
#         fecha_reporte fecha_atencion         colonia  \
# 0  Diciembre 30, 2022           None      Balderrama
# 1  Diciembre 30, 2022           None        Olivares
# 2  Diciembre 29, 2022           None     Solidaridad
# 3  Diciembre 29, 2022           None  Sahuaro Indeco
# 4  Diciembre 29, 2022           None  Sahuaro Indeco
#
#                                            direccion  \
# 0  Othon Almada 330-A, C. Arizona esquina, Balder...
# 1  Cjon. Ímuris 56B, Olivares, 83180 Hermosillo, ...
# 2  Nudo Mixteco 193, Solidaridad, 83116 Hermosill...
# 3  Av. José María Mendoza 1509A, Sahuaro Indeco, ...
# 4  Av. José María Mendoza 6, Sahuaro Indeco, 8318...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %% [markdown]
# ## Tratando datos de Fecha

# %% [markdown]
# Dado que en el dataframe aparecen fechas que no están en formato datetime necesitamos convertirlas para poder tratarlas de manera correcta.

# %% [markdown]
# Lo primero que podemos notar es que las fechas del dataframe consisten en el nombre del mes, seguido del día en numero y el año en 4 dígitos.

# %% [markdown]
# Para comenzar vamos a hacer un diccionario para asignar a cada nombre del mes su numero de mes correspondiente

# %%
#Mappeando meses del año a numeros
month_map = { 'Enero': 1, 'Febrero': 2, 'Marzo': 3, 'Abril': 4, 'Mayo': 5, 'Junio': 6,
              'Julio': 7, 'Agosto': 8, 'Septiembre': 9, 'Octubre': 10, 'Noviembre': 11, 'Diciembre': 12 }

# %% [markdown]
# Vamos a comprobar el tipo de dato que son las fechas del dataframe

# %%
#viendo el tipo de dato que es fecha_reporte
df['fecha_reporte'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Otra cosa que notamos con el método "tail" es que hay algunas filas sin fechas para la columna de fecha_atencion, lo que siguiere que el bache no se ha atendido pero es necesario tomar en cuenta esto para poder manejar la transformacion de las fechas de mejor manera.

# %% [markdown]
# ### Funcion para tratado de columnas de fecha

# %%
def procesar_columna_fecha(df, col, month_map):
    # Máscara para filas válidas (no nulas)
    mask = df[col].notna()
    #print(f"[DEBUG] Filas válidas para '{col}': {mask.sum()} de {len(df)}")

    # Si no hay filas válidas, omite el procesamiento
    if mask.sum() == 0:
        #print(f"[DEBUG] No hay filas válidas para '{col}'. Se omite el procesamiento.")
        return df

    # Convertir a string
    df.loc[mask, col] = df.loc[mask, col].astype(str)
    #print(f"[DEBUG] Tipos tras astype(str): {df.loc[mask, col].apply(type).unique()}")

    # Limpiar caracteres no alfanuméricos
    df.loc[mask, col] = df.loc[mask, col].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

    # Reemplazar nombres de meses por números
    for month, num in month_map.items():
        df.loc[mask, col] = df.loc[mask, col].str.replace(month, str(num), regex=False)

    # Cambiar None por NA
    df[col] = df[col].replace({None: pd.NA})

    # DEBUG: Ver ejemplos antes del split
    #print(f"[DEBUG] Ejemplo de valores antes del split en '{col}':")
    #print(df.loc[mask, col].head(10).to_list())

    # Split en 3 columnas para día mes y año
    splitted = df[col].str.split(' ', expand=True)
    #print(f"[DEBUG] Shape del split: {splitted.shape}")
    #print(f"[DEBUG] Primeras filas del split:\n{splitted.head(10)}")

    # Verifica si el split tiene exactamente 3 columnas
    if splitted.shape[1] != 3:
        #print(f"[ERROR] El split produjo {splitted.shape[1]} columnas en vez de 3. Revisa el formato de las fechas en '{col}'.")
        return df  # O puedes lanzar un error si prefieres: raise ValueError(...)

    df[['month', 'day', 'year']] = splitted

    # Rellenar vacíos con "0"
    df['day'] = df['day'].fillna('0')
    df['month'] = df['month'].fillna('0')
    df['year'] = df['year'].fillna('0')

    # Unir a datetime
    df[col] = pd.to_datetime(df[['day', 'month', 'year']], errors='coerce')

    # Eliminar columnas auxiliares
    df = df.drop(columns=['day', 'month', 'year'])
    return df

# %% [markdown]
# Aplicamos la funcion anterior a ambas columnas

# %%
df = procesar_columna_fecha(df, 'fecha_reporte', month_map)
df = procesar_columna_fecha(df, 'fecha_atencion', month_map)

# %%
df.head(5)
# Out:
#     latitude   longitude       date neighborhoods    id no_reparemos  folio  \
# 0  29.102150 -110.975015 2022-12-30          [50]  9027       1/2023    NaN
# 1  29.099811 -110.980192 2022-12-30         [397]  9028       2/2023    NaN
# 2  29.139033 -111.007460 2022-12-29         [589]  9029       3/2023    NaN
# 3  29.102135 -111.001896 2022-12-29         [545]  9030       4/2023    NaN
# 4  29.102142 -110.998482 2022-12-29         [545]  9031       5/2023    NaN
#
#   fecha_reporte fecha_atencion         colonia  \
# 0    2022-12-30            NaT      Balderrama
# 1    2022-12-30            NaT        Olivares
# 2    2022-12-29            NaT     Solidaridad
# 3    2022-12-29            NaT  Sahuaro Indeco
# 4    2022-12-29            NaT  Sahuaro Indeco
#
#                                            direccion  \
# 0  Othon Almada 330-A, C. Arizona esquina, Balder...
# 1  Cjon. Ímuris 56B, Olivares, 83180 Hermosillo, ...
# 2  Nudo Mixteco 193, Solidaridad, 83116 Hermosill...
# 3  Av. José María Mendoza 1509A, Sahuaro Indeco, ...
# 4  Av. José María Mendoza 6, Sahuaro Indeco, 8318...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.tail()
# Out:
#        latitude   longitude       date neighborhoods     id no_reparemos  \
# 4886  29.140324 -110.975054 2023-12-28         [729]  14281    5255/2023
# 4887  29.091493 -110.957280 2023-12-28         [551]  14282    5256/2023
# 4888  29.127477 -111.004216 2023-12-28         [614]  14283    5257/2023
# 4889  29.126429 -111.012014 2023-12-28         [729]  14284    5258/2023
# 4890  29.148924 -111.006597 2023-12-28         [462]  14285    5259/2023
#
#       folio fecha_reporte fecha_atencion               colonia  \
# 4886    NaN    2023-12-28            NaT    Vialidad Principal
# 4887    NaN    2023-12-28            NaT            San Benito
# 4888    NaN    2023-12-28            NaT  Unión de Ladrilleros
# 4889    NaN    2023-12-28            NaT    Vialidad Principal
# 4890    NaN    2023-12-28            NaT   Privadas Del Bosque
#
#                                               direccion  \
# 4886  C. de la Reforma 314, Heberto Castillo, 83106 ...
# 4887  Av. Zacatecas SN-S, San Benito, 83190 Hermosil...
# 4888  Av. Joaquín Gabriel Durán 32, Union De Ladrill...
# 4889  Avenida Joaquin Duran & Calle Carlos Balderram...
# 4890  Blvd Agustin F Zamora, Zona Industrial, 83117 ...
#
#                                                imagenes
# 4886  [https://bachometro.hermosillo.gob.mx/images/f...
# 4887  [https://bachometro.hermosillo.gob.mx/images/f...
# 4888  [https://bachometro.hermosillo.gob.mx/images/f...
# 4889  [https://bachometro.hermosillo.gob.mx/images/f...
# 4890  [https://bachometro.hermosillo.gob.mx/images/f...

# %% [markdown]
# Comprobamos que ahora las columnas de fechas sean del tipo datetime

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4891 entries, 0 to 4890
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        4891 non-null   float64
#  1   longitude       4891 non-null   float64
#  2   date            4891 non-null   datetime64[ns]
#  3   neighborhoods   4891 non-null   object
#  4   id              4891 non-null   int64
#  5   no_reparemos    4891 non-null   object
#  6   folio           318 non-null    float64
#  7   fecha_reporte   4891 non-null   datetime64[ns]
#  8   fecha_atencion  323 non-null    datetime64[ns]
#  9   colonia         4891 non-null   object
#  10  direccion       4891 non-null   object
#  11  imagenes        4891 non-null   object
# dtypes: datetime64[ns](3), float64(3), int64(1), object(5)
# memory usage: 458.7+ KB

# %%
#viendo nans en fecha_atencion
df['fecha_atencion'].isna().sum()
# Out:
# np.int64(4568)

# %% [markdown]
# Eliminamos más columnas inecesarias o redundantes.

# %%
#Droppeando imagenes
df = df.drop(columns=['imagenes'])
#Droppeando Date ya que es lo mismo que fecha_atencion
df = df.drop(columns=['date'])
#Tampoco necesitamos neighborhood
df = df.drop(columns=['neighborhoods'])
#droppeando no_reparemos
df = df.drop(columns=['no_reparemos'])

# %%
df.head()
# Out:
#     latitude   longitude    id  folio fecha_reporte fecha_atencion  \
# 0  29.102150 -110.975015  9027    NaN    2022-12-30            NaT
# 1  29.099811 -110.980192  9028    NaN    2022-12-30            NaT
# 2  29.139033 -111.007460  9029    NaN    2022-12-29            NaT
# 3  29.102135 -111.001896  9030    NaN    2022-12-29            NaT
# 4  29.102142 -110.998482  9031    NaN    2022-12-29            NaT
#
#           colonia                                          direccion
# 0      Balderrama  Othon Almada 330-A, C. Arizona esquina, Balder...
# 1        Olivares  Cjon. Ímuris 56B, Olivares, 83180 Hermosillo, ...
# 2     Solidaridad  Nudo Mixteco 193, Solidaridad, 83116 Hermosill...
# 3  Sahuaro Indeco  Av. José María Mendoza 1509A, Sahuaro Indeco, ...
# 4  Sahuaro Indeco  Av. José María Mendoza 6, Sahuaro Indeco, 8318...

# %% [markdown]
# ## Revisando si existen duplicados, en filas y variables específicas u otras inconsistencias

# %%
#Buscando valores repetidos en id
df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Buscaando valores nulos
df.isnull().sum()
# Out:
# latitude             0
# longitude            0
# id                   0
# folio             4573
# fecha_reporte        0
# fecha_atencion    4568
# colonia              0
# direccion            0
# dtype: int64

# %%
#Buscando filas duplicadas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4891 entries, 0 to 4890
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        4891 non-null   float64
#  1   longitude       4891 non-null   float64
#  2   id              4891 non-null   int64
#  3   folio           318 non-null    float64
#  4   fecha_reporte   4891 non-null   datetime64[ns]
#  5   fecha_atencion  323 non-null    datetime64[ns]
#  6   colonia         4891 non-null   object
#  7   direccion       4891 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 305.8+ KB
