# %%
import pandas as pd

# Cargar el archivo JSON
df = pd.read_json("../../data/raw/baches_2021.json")

# Mostrar las primeras filas
df.head(5)
# Out:
#     latitude   longitude       date neighborhoods material  \
# 0  29.094161 -110.969471 2021-10-18         [551]  Asfalto
# 1  29.124060 -110.971318 2021-10-19         [601]  Asfalto
# 2  29.123985 -110.971286 2021-10-19         [601]  Asfalto
# 3  29.128777 -110.953926 2021-10-21          [49]  Asfalto
# 4  29.083809 -111.042101 2021-10-04          [74]  Asfalto
#
#                                          description  id no_reparemos  folio  \
# 0  Hay un bache en la calle, y los carros se golp...   1       1/2021    105
# 1  Buen dia! Para reportar pavimento dañado, bach...   4       4/2021    332
# 2  Buen dia! Para reportar pavimento dañado, bach...   5       5/2021    333
# 3  toda la calle desde el blvd Morelos tiene vari...   6       6/2021   1072
# 4  C. SOLICITA BACHEO ASEGURA REPORTANTE QUE ES P...   7       7/2021   1084
#
#         fecha_reporte    fecha_atencion                       colonia  \
# 0      Julio 31, 2020  Octubre 18, 2021                    San Benito
# 1     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 2     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 3  Diciembre 10, 2020  Octubre 21, 2021                       Bachoco
# 4  Diciembre 11, 2020  Octubre 04, 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                          descripcion  \
# 0  Hay un bache en la calle, y los carros se golp...
# 1  Buen dia! Para reportar pavimento dañado, bach...
# 2  Buen dia! Para reportar pavimento dañado, bach...
# 3  toda la calle desde el blvd Morelos tiene vari...
# 4  C. SOLICITA BACHEO ASEGURA REPORTANTE QUE ES P...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        100 non-null    float64
#  1   longitude       100 non-null    float64
#  2   date            100 non-null    datetime64[ns]
#  3   neighborhoods   100 non-null    object
#  4   material        100 non-null    object
#  5   description     100 non-null    object
#  6   id              100 non-null    int64
#  7   no_reparemos    100 non-null    object
#  8   folio           100 non-null    int64
#  9   fecha_reporte   100 non-null    object
#  10  fecha_atencion  100 non-null    object
#  11  colonia         100 non-null    object
#  12  direccion       100 non-null    object
#  13  descripcion     100 non-null    object
#  14  imagenes        100 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(10)
# memory usage: 11.8+ KB

# %%
#droppeando laas columnas de descripción ya que no son necesarias para el análisis
df = df.drop(columns=['descripcion'])
df = df.drop(columns=['description'])

# %%
#Revisando valores unicos de Material
df['material'].unique()
# Out:
# array(['Asfalto'], dtype=object)

# %%
# Droppeando material ya que no aporta informacion relevante
df = df.drop(columns=['material'])

# %%
df.head()
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos  folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021    105
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021    332
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021    333
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021   1072
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021   1084
#
#         fecha_reporte    fecha_atencion                       colonia  \
# 0      Julio 31, 2020  Octubre 18, 2021                    San Benito
# 1     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 2     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 3  Diciembre 10, 2020  Octubre 21, 2021                       Bachoco
# 4  Diciembre 11, 2020  Octubre 04, 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
#Mappeando meses del año a numeros
month_map = { 'Enero': 1, 'Febrero': 2, 'Marzo': 3, 'Abril': 4, 'Mayo': 5, 'Junio': 6,
              'Julio': 7, 'Agosto': 8, 'Septiembre': 9, 'Octubre': 10, 'Noviembre': 11, 'Diciembre': 12 }

# %%
#viendo el tipo de dato que es fecha_reporte
df['fecha_reporte'].dtype
#convirtiendo a string
df['fecha_reporte'] = df['fecha_reporte'].astype(str)
#usando regex para eliminar cualquier caracrter que no sea una letra o u numero
df['fecha_reporte'] = df['fecha_reporte'].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

# %%
df['fecha_reporte'] = df['fecha_reporte'].astype(str)

# %%
#Usando regex para cambiar el nombre del mes por su numero correspondiente
for month, num in month_map.items():
    df['fecha_reporte'] = df['fecha_reporte'].str.replace(month, str(num), regex=False)

# %%
df.head(5)
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos  folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021    105
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021    332
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021    333
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021   1072
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021   1084
#
#   fecha_reporte    fecha_atencion                       colonia  \
# 0     7 31 2020  Octubre 18, 2021                    San Benito
# 1     8 22 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 2     8 22 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 3    12 10 2020  Octubre 21, 2021                       Bachoco
# 4    12 11 2020  Octubre 04, 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
#separando fecha_reporte en dia, mes y año
df[['month', 'day', 'year']] = df['fecha_reporte'].str.split(' ', expand=True)

# %%
#Eliminando columna fecha_reporte
df = df.drop(columns=['fecha_reporte'])

# %%
#Recreando fecha_reporte en formato datetime
df['fecha_reporte'] = pd.to_datetime(df[['day', 'month', 'year']])

# %%
df.head()
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos  folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021    105
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021    332
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021    333
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021   1072
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021   1084
#
#      fecha_atencion                       colonia  \
# 0  Octubre 18, 2021                    San Benito
# 1  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 2  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 3  Octubre 21, 2021                       Bachoco
# 4  Octubre 04, 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes month day  year  \
# 0  [https://bachometro.hermosillo.gob.mx/images/f...     7  31  2020
# 1  [https://bachometro.hermosillo.gob.mx/images/f...     8  22  2020
# 2  [https://bachometro.hermosillo.gob.mx/images/f...     8  22  2020
# 3  [https://bachometro.hermosillo.gob.mx/images/f...    12  10  2020
# 4  [https://bachometro.hermosillo.gob.mx/images/f...    12  11  2020
#
#   fecha_reporte
# 0    2020-07-31
# 1    2020-08-22
# 2    2020-08-22
# 3    2020-12-10
# 4    2020-12-11

# %%
#Cambiando el nombre del mes en fecha_atencion a su numero correspondeinte
df['fecha_atencion'] = df['fecha_atencion'].astype(str)
for month, num in month_map.items():
    df['fecha_atencion'] = df['fecha_atencion'].str.replace(month, str(num), regex=False)
#Quitando caracteres no alfanummericos
df['fecha_atencion'] = df['fecha_atencion'].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

# %%
df.head()
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos  folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021    105
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021    332
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021    333
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021   1072
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021   1084
#
#   fecha_atencion                       colonia  \
# 0     10 18 2021                    San Benito
# 1     10 19 2021  Fraccionamiento Tierra Nueva
# 2     10 19 2021  Fraccionamiento Tierra Nueva
# 3     10 21 2021                       Bachoco
# 4     10 04 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes month day  year  \
# 0  [https://bachometro.hermosillo.gob.mx/images/f...     7  31  2020
# 1  [https://bachometro.hermosillo.gob.mx/images/f...     8  22  2020
# 2  [https://bachometro.hermosillo.gob.mx/images/f...     8  22  2020
# 3  [https://bachometro.hermosillo.gob.mx/images/f...    12  10  2020
# 4  [https://bachometro.hermosillo.gob.mx/images/f...    12  11  2020
#
#   fecha_reporte
# 0    2020-07-31
# 1    2020-08-22
# 2    2020-08-22
# 3    2020-12-10
# 4    2020-12-11

# %%
#Separando fecha_atencion en month, day y year
df[['month', 'day', 'year']] = df['fecha_atencion'].str.split(' ', expand=True)
#droppeando fecha_atencion
df = df.drop(columns=['fecha_atencion'])
#pasando a datetime
df['fecha_atencion'] = pd.to_datetime(df[['day', 'month', 'year']])
#droppeando columnas day, month y year
df = df.drop(columns=['day', 'month', 'year'])
df.head()
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos  folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021    105
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021    332
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021    333
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021   1072
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021   1084
#
#                         colonia  \
# 0                    San Benito
# 1  Fraccionamiento Tierra Nueva
# 2  Fraccionamiento Tierra Nueva
# 3                       Bachoco
# 4      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes fecha_reporte  \
# 0  [https://bachometro.hermosillo.gob.mx/images/f...    2020-07-31
# 1  [https://bachometro.hermosillo.gob.mx/images/f...    2020-08-22
# 2  [https://bachometro.hermosillo.gob.mx/images/f...    2020-08-22
# 3  [https://bachometro.hermosillo.gob.mx/images/f...    2020-12-10
# 4  [https://bachometro.hermosillo.gob.mx/images/f...    2020-12-11
#
#   fecha_atencion
# 0     2021-10-18
# 1     2021-10-19
# 2     2021-10-19
# 3     2021-10-21
# 4     2021-10-04

# %%
#Droppeando imagenes
df = df.drop(columns=['imagenes'])
#Droppeando Date ya que es lo mismo que fecha_atencion
df = df.drop(columns=['date'])
#Tampoco necesitamos neighborhood
df = df.drop(columns=['neighborhoods'])

# %%
#Buscando valores repetidos en id
df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Buscaando valores nulos
df.isnull().sum()
# Out:
# latitude          0
# longitude         0
# id                0
# no_reparemos      0
# folio             0
# colonia           0
# direccion         0
# fecha_reporte     0
# fecha_atencion    0
# dtype: int64

# %%
#Buscando filas duplicadas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        100 non-null    float64
#  1   longitude       100 non-null    float64
#  2   id              100 non-null    int64
#  3   no_reparemos    100 non-null    object
#  4   folio           100 non-null    int64
#  5   colonia         100 non-null    object
#  6   direccion       100 non-null    object
#  7   fecha_reporte   100 non-null    datetime64[ns]
#  8   fecha_atencion  100 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(2), object(3)
# memory usage: 7.2+ KB
