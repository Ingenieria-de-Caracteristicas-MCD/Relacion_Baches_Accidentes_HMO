# %%
import pandas as pd

# Cargar el archivo JSON
df = pd.read_json("../../data/raw/baches_2021.json")

# Mostrar las primeras filas
df.head(5)
# Out:
#     latitude   longitude       date neighborhoods material  \
# 0  29.094161 -110.969471 2021-10-18         [551]  Asfalto
# 1  29.124060 -110.971318 2021-10-19         [601]  Asfalto
# 2  29.123985 -110.971286 2021-10-19         [601]  Asfalto
# 3  29.128777 -110.953926 2021-10-21          [49]  Asfalto
# 4  29.083809 -111.042101 2021-10-04          [74]  Asfalto
#
#                                          description  id no_reparemos   folio  \
# 0  Hay un bache en la calle, y los carros se golp...   1       1/2021   105.0
# 1  Buen dia! Para reportar pavimento dañado, bach...   4       4/2021   332.0
# 2  Buen dia! Para reportar pavimento dañado, bach...   5       5/2021   333.0
# 3  toda la calle desde el blvd Morelos tiene vari...   6       6/2021  1072.0
# 4  C. SOLICITA BACHEO ASEGURA REPORTANTE QUE ES P...   7       7/2021  1084.0
#
#         fecha_reporte    fecha_atencion                       colonia  \
# 0      Julio 31, 2020  Octubre 18, 2021                    San Benito
# 1     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 2     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 3  Diciembre 10, 2020  Octubre 21, 2021                       Bachoco
# 4  Diciembre 11, 2020  Octubre 04, 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                          descripcion  \
# 0  Hay un bache en la calle, y los carros se golp...
# 1  Buen dia! Para reportar pavimento dañado, bach...
# 2  Buen dia! Para reportar pavimento dañado, bach...
# 3  toda la calle desde el blvd Morelos tiene vari...
# 4  C. SOLICITA BACHEO ASEGURA REPORTANTE QUE ES P...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.tail()
# Out:
#       latitude   longitude       date neighborhoods material  \
# 520  29.105387 -110.962350 2021-10-01          [50]  Asfalto
# 521  29.097471 -110.961064 2021-10-04         [551]  Asfalto
# 522  29.114354 -110.963834 2021-10-06         [226]  Asfalto
# 523  29.107500 -110.962700 2021-10-11          [50]  Asfalto
# 524  29.086041 -110.960687 2021-10-21         [551]  Asfalto
#
#                                            description    id no_reparemos  \
# 520  Baches en Reyes entre José San Healy y Perifér...  1317    1229/2021
# 521   Baches en Reyes entre Veracruz y José San Healy.  1318    1230/2021
# 522                Baches en Reyes entre Uno y Cuatro.  1319    1231/2021
# 523  Baches en Reyes entre Mendoza y Periférico Norte.  1320    1232/2021
# 524  Baches en Reyes entre Luis Encinas y Gastón Ma...  1321    1233/2021
#
#      folio     fecha_reporte fecha_atencion       colonia  \
# 520    NaN  Octubre 01, 2021           None    Balderrama
# 521    NaN  Octubre 04, 2021           None    San Benito
# 522    NaN  Octubre 06, 2021           None  Jesús García
# 523    NaN  Octubre 11, 2021           None    Balderrama
# 524    NaN  Octubre 21, 2021           None    San Benito
#
#                                              direccion  \
# 520  Calle Gral. Bernardo Reyes 229, Balderrama, 83...
# 521  Av Quintana Roo 113, San Benito, 83190 Hermosi...
# 522  Av. Tres 190, Jesus Garcia, 83140 Hermosillo, ...
# 523  Av Enrique Quijada 111, Balderrama, 83180 Herm...
# 524  Calle Gral. Bernardo Reyes SN-S GUARDERIA PARA...
#
#                                            descripcion  \
# 520  Baches en Reyes entre José San Healy y Perifér...
# 521   Baches en Reyes entre Veracruz y José San Healy.
# 522                Baches en Reyes entre Uno y Cuatro.
# 523  Baches en Reyes entre Mendoza y Periférico Norte.
# 524  Baches en Reyes entre Luis Encinas y Gastón Ma...
#
#                                               imagenes
# 520  [https://bachometro.hermosillo.gob.mx/images/f...
# 521  [https://bachometro.hermosillo.gob.mx/images/f...
# 522  [https://bachometro.hermosillo.gob.mx/images/f...
# 523  [https://bachometro.hermosillo.gob.mx/images/f...
# 524  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        525 non-null    float64
#  1   longitude       525 non-null    float64
#  2   date            525 non-null    datetime64[ns]
#  3   neighborhoods   525 non-null    object
#  4   material        525 non-null    object
#  5   description     525 non-null    object
#  6   id              525 non-null    int64
#  7   no_reparemos    525 non-null    object
#  8   folio           466 non-null    float64
#  9   fecha_reporte   525 non-null    object
#  10  fecha_atencion  434 non-null    object
#  11  colonia         525 non-null    object
#  12  direccion       525 non-null    object
#  13  descripcion     525 non-null    object
#  14  imagenes        525 non-null    object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 61.7+ KB

# %%
#droppeando laas columnas de descripción ya que no son necesarias para el análisis
df = df.drop(columns=['descripcion'])
df = df.drop(columns=['description'])

# %%
#Revisando valores unicos de Material
df['material'].unique()
# Out:
# array(['Asfalto', 'Concreto'], dtype=object)

# %%
# Droppeando material ya que no aporta informacion relevante
df = df.drop(columns=['material'])

# %%
df.head()
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos   folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021   105.0
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021   332.0
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021   333.0
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021  1072.0
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021  1084.0
#
#         fecha_reporte    fecha_atencion                       colonia  \
# 0      Julio 31, 2020  Octubre 18, 2021                    San Benito
# 1     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 2     Agosto 22, 2020  Octubre 19, 2021  Fraccionamiento Tierra Nueva
# 3  Diciembre 10, 2020  Octubre 21, 2021                       Bachoco
# 4  Diciembre 11, 2020  Octubre 04, 2021      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
#Mappeando meses del año a numeros
month_map = { 'Enero': 1, 'Febrero': 2, 'Marzo': 3, 'Abril': 4, 'Mayo': 5, 'Junio': 6,
              'Julio': 7, 'Agosto': 8, 'Septiembre': 9, 'Octubre': 10, 'Noviembre': 11, 'Diciembre': 12 }

# %%
#viendo el tipo de dato que es fecha_reporte
df['fecha_reporte'].dtype
# Out:
# dtype('O')

# %%
def procesar_columna_fecha(df, col, month_map):
    # Máscara para filas válidas (no nulas)
    mask = df[col].notna()
    #print(f"[DEBUG] Filas válidas para '{col}': {mask.sum()} de {len(df)}")

    # Si no hay filas válidas, omite el procesamiento
    if mask.sum() == 0:
        #print(f"[DEBUG] No hay filas válidas para '{col}'. Se omite el procesamiento.")
        return df

    # Convertir a string
    df.loc[mask, col] = df.loc[mask, col].astype(str)
    #print(f"[DEBUG] Tipos tras astype(str): {df.loc[mask, col].apply(type).unique()}")

    # Limpiar caracteres no alfanuméricos
    df.loc[mask, col] = df.loc[mask, col].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

    # Reemplazar nombres de meses por números
    for month, num in month_map.items():
        df.loc[mask, col] = df.loc[mask, col].str.replace(month, str(num), regex=False)

    # Cambiar None por NA
    df[col] = df[col].replace({None: pd.NA})

    # DEBUG: Ver ejemplos antes del split
    #print(f"[DEBUG] Ejemplo de valores antes del split en '{col}':")
    #print(df.loc[mask, col].head(10).to_list())

    # Split en 3 columnas
    splitted = df[col].str.split(' ', expand=True)
    #print(f"[DEBUG] Shape del split: {splitted.shape}")
    #print(f"[DEBUG] Primeras filas del split:\n{splitted.head(10)}")

    # Verifica si el split tiene exactamente 3 columnas
    if splitted.shape[1] != 3:
        #print(f"[ERROR] El split produjo {splitted.shape[1]} columnas en vez de 3. Revisa el formato de las fechas en '{col}'.")
        return df  # O puedes lanzar un error si prefieres: raise ValueError(...)

    df[['month', 'day', 'year']] = splitted

    # Rellenar vacíos con "0"
    df['day'] = df['day'].fillna('0')
    df['month'] = df['month'].fillna('0')
    df['year'] = df['year'].fillna('0')

    # Unir a datetime
    df[col] = pd.to_datetime(df[['day', 'month', 'year']], errors='coerce')

    # Eliminar columnas auxiliares
    df = df.drop(columns=['day', 'month', 'year'])
    return df

# %%
df = procesar_columna_fecha(df, 'fecha_reporte', month_map)
df = procesar_columna_fecha(df, 'fecha_atencion', month_map)

# %%
df.head(5)
# Out:
#     latitude   longitude       date neighborhoods  id no_reparemos   folio  \
# 0  29.094161 -110.969471 2021-10-18         [551]   1       1/2021   105.0
# 1  29.124060 -110.971318 2021-10-19         [601]   4       4/2021   332.0
# 2  29.123985 -110.971286 2021-10-19         [601]   5       5/2021   333.0
# 3  29.128777 -110.953926 2021-10-21          [49]   6       6/2021  1072.0
# 4  29.083809 -111.042101 2021-10-04          [74]   7       7/2021  1084.0
#
#   fecha_reporte fecha_atencion                       colonia  \
# 0    2020-07-31     2021-10-18                    San Benito
# 1    2020-08-22     2021-10-19  Fraccionamiento Tierra Nueva
# 2    2020-08-22     2021-10-19  Fraccionamiento Tierra Nueva
# 3    2020-12-10     2021-10-21                       Bachoco
# 4    2020-12-11     2021-10-04      Campo Grande Residencial
#
#                                            direccion  \
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...
#
#                                             imagenes
# 0  [https://bachometro.hermosillo.gob.mx/images/f...
# 1  [https://bachometro.hermosillo.gob.mx/images/f...
# 2  [https://bachometro.hermosillo.gob.mx/images/f...
# 3  [https://bachometro.hermosillo.gob.mx/images/f...
# 4  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.tail()
# Out:
#       latitude   longitude       date neighborhoods    id no_reparemos  folio  \
# 520  29.105387 -110.962350 2021-10-01          [50]  1317    1229/2021    NaN
# 521  29.097471 -110.961064 2021-10-04         [551]  1318    1230/2021    NaN
# 522  29.114354 -110.963834 2021-10-06         [226]  1319    1231/2021    NaN
# 523  29.107500 -110.962700 2021-10-11          [50]  1320    1232/2021    NaN
# 524  29.086041 -110.960687 2021-10-21         [551]  1321    1233/2021    NaN
#
#     fecha_reporte fecha_atencion       colonia  \
# 520    2021-10-01            NaT    Balderrama
# 521    2021-10-04            NaT    San Benito
# 522    2021-10-06            NaT  Jesús García
# 523    2021-10-11            NaT    Balderrama
# 524    2021-10-21            NaT    San Benito
#
#                                              direccion  \
# 520  Calle Gral. Bernardo Reyes 229, Balderrama, 83...
# 521  Av Quintana Roo 113, San Benito, 83190 Hermosi...
# 522  Av. Tres 190, Jesus Garcia, 83140 Hermosillo, ...
# 523  Av Enrique Quijada 111, Balderrama, 83180 Herm...
# 524  Calle Gral. Bernardo Reyes SN-S GUARDERIA PARA...
#
#                                               imagenes
# 520  [https://bachometro.hermosillo.gob.mx/images/f...
# 521  [https://bachometro.hermosillo.gob.mx/images/f...
# 522  [https://bachometro.hermosillo.gob.mx/images/f...
# 523  [https://bachometro.hermosillo.gob.mx/images/f...
# 524  [https://bachometro.hermosillo.gob.mx/images/f...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        525 non-null    float64
#  1   longitude       525 non-null    float64
#  2   date            525 non-null    datetime64[ns]
#  3   neighborhoods   525 non-null    object
#  4   id              525 non-null    int64
#  5   no_reparemos    525 non-null    object
#  6   folio           466 non-null    float64
#  7   fecha_reporte   525 non-null    datetime64[ns]
#  8   fecha_atencion  434 non-null    datetime64[ns]
#  9   colonia         525 non-null    object
#  10  direccion       525 non-null    object
#  11  imagenes        525 non-null    object
# dtypes: datetime64[ns](3), float64(3), int64(1), object(5)
# memory usage: 49.3+ KB

# %%
#viendo nans en fecha_atencion
df['fecha_atencion'].isna().sum()
# Out:
# np.int64(91)

# %%
#Droppeando imagenes
df = df.drop(columns=['imagenes'])
#Droppeando Date ya que es lo mismo que fecha_atencion
df = df.drop(columns=['date'])
#Tampoco necesitamos neighborhood
df = df.drop(columns=['neighborhoods'])
#droppeando no_reparemos
df = df.drop(columns=['no_reparemos'])

# %%
df.head()
# Out:
#     latitude   longitude  id   folio fecha_reporte fecha_atencion  \
# 0  29.094161 -110.969471   1   105.0    2020-07-31     2021-10-18
# 1  29.124060 -110.971318   4   332.0    2020-08-22     2021-10-19
# 2  29.123985 -110.971286   5   333.0    2020-08-22     2021-10-19
# 3  29.128777 -110.953926   6  1072.0    2020-12-10     2021-10-21
# 4  29.083809 -111.042101   7  1084.0    2020-12-11     2021-10-04
#
#                         colonia  \
# 0                    San Benito
# 1  Fraccionamiento Tierra Nueva
# 2  Fraccionamiento Tierra Nueva
# 3                       Bachoco
# 4      Campo Grande Residencial
#
#                                            direccion
# 0  Calle Francisco Monteverde 75, San Benito, 831...
# 1  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 2  Av. Enguerrando Tapia Quijada 78, Fraccionamie...
# 3  Av. el Bachoco 24, Bachoco, 83148 Hermosillo, ...
# 4  BULEVAR LUIS DONALDO COLOSIO  ESQ. , CAMPOGRAN...

# %%
#Buscando valores repetidos en id
df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Buscaando valores nulos
df.isnull().sum()
# Out:
# latitude           0
# longitude          0
# id                 0
# folio             59
# fecha_reporte      0
# fecha_atencion    91
# colonia            0
# direccion          0
# dtype: int64

# %%
#Buscando filas duplicadas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        525 non-null    float64
#  1   longitude       525 non-null    float64
#  2   id              525 non-null    int64
#  3   folio           466 non-null    float64
#  4   fecha_reporte   525 non-null    datetime64[ns]
#  5   fecha_atencion  434 non-null    datetime64[ns]
#  6   colonia         525 non-null    object
#  7   direccion       525 non-null    object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 32.9+ KB
